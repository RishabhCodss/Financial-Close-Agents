# %% [markdown]
# # Data collection

# %% [markdown]
# Dataset source - https://www.kaggle.com/datasets/benchmarkteam/benchrec-real-world-cash-reconciliation-dataset

# %% [markdown]
# # Import data and required packages

# %%
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Importing data

# %%
df = pd.read_csv('D:\Projects\Financial Close Agents\data\dataset.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18072\3442937514.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('D:\Projects\Financial Close Agents\data\dataset.csv')

# %% [markdown]
# ## Top 5 records

# %%
df.head()
# Out:
#         matchId   matchDate matchRule   matchedBy  wasPreviouslyMismatched  \
# 0  504385986027  2015-03-12    RULE 4  FAECAL IPL                        0
# 1  504385986027  2015-03-12       NaN  FAECAL IPL                        0
# 2  504385986027  2015-03-12    RULE 4  FAECAL IPL                        0
# 3  870402401618  2015-03-25    RULE 4  FAECAL IPL                        0
# 4  870402401618  2015-03-25    RULE 4  FAECAL IPL                        0
#
#   A_transactionType          A_id  \
# 0               NaN           NaN
# 1               NaN           NaN
# 2                 A  8.061604e+11
# 3                 A  9.271706e+11
# 4               NaN           NaN
#
#                                         A_allocation A_importDate  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2  USD_2015-03-08_ACC#00001_66412     66510665106...   2015-03-12
# ...

# %%
df.shape
# Out:
# (149854, 27)

# %% [markdown]
# # Dataset checks

# %% [markdown]
# ## Checking missing entry

# %%
df.isna().sum()
# Out:
# matchId                        0
# matchDate                      0
# matchRule                    582
# matchedBy                      0
# wasPreviouslyMismatched        0
# A_transactionType          68975
# A_id                       68975
# A_allocation               68975
# A_importDate               68975
# A_debitOrCredit            68975
# A_amount                   68975
# A_valueDate                68975
# A_currencyCode             68975
# A_account                  68975
# A_transactionReferences    68975
# A_transactionAttributes    68978
# B_transactionType          80879
# B_id                       80879
# B_importDate               80879
# B_debitOrCredit            80879
# B_amount                   80879
# B_valueDate                80879
# B_currencyCode             80879
# B_account                  80879
# B_transactionReferences    80879
# B_transactionAttributes    92568
# targetAllocation           82114
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 149854 entries, 0 to 149853
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   matchId                  149854 non-null  int64
#  1   matchDate                149854 non-null  str
#  2   matchRule                149272 non-null  str
#  3   matchedBy                149854 non-null  str
#  4   wasPreviouslyMismatched  149854 non-null  int64
#  5   A_transactionType        80879 non-null   str
#  6   A_id                     80879 non-null   float64
#  7   A_allocation             80879 non-null   str
#  8   A_importDate             80879 non-null   str
#  9   A_debitOrCredit          80879 non-null   str
#  10  A_amount                 80879 non-null   float64
#  11  A_valueDate              80879 non-null   str
#  12  A_currencyCode           80879 non-null   str
#  13  A_account                80879 non-null   str
# ...

# %% [markdown]
# # Data Cleaning

# %%
df['wasPreviouslyMismatched'].unique()
# Out:
# array([0])
